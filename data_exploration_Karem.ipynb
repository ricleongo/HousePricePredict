# %% [markdown]
#    ## Housing prices, data analysis and predictions
# ___
#
#     1 Determining what is the price changes per county from 2010 to 2016
#
#
# ## Census API
#
#
# #### Code and Description
# ____
#
#
# * B01003_001E = Population
# * B01002_001E = Median Age
# * B19013_001E = Household Income
# * B19301_001E = Per Capita Income
# * B25077_001E = Median Value Housing Units
# * B17001_002E = Poverty Count
# ____
#
#
# <br />
# <br />
#
# ## FIPS (Federal Information Processing Standards)
#
# #### State FIPS code
# * 13 Georgia
#
# #### County FIPS code
# ___
#
# * 13121 - Fulton County
# * 13135 - Gwinnett County
# * 13089 - DeKalb County
# * 13067 - Cobb County
# * 13063 - Clayton County
# * 13057 - Cherokee County
# * 13151 - Henry County
# * 13117 - Forsyth County
# * 13097 - Douglas County
# ___

# %%
## Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce
import requests
from census import Census
import gmaps
from scipy.stats import sem
from scipy.stats import linregress
from IPython.display import display, HTML, clear_output

# Census & gmaps API Keys
from security.census_key import (api_key, gkey)

# Internal functionality
from functions import print_message,calculate_percentage,get_column_des,get_merged_data,get_fields,get_filters,print_message,print_plot,print_bars, get_zillow_column_des, get_std_error, print_trendline

zillow_csv = './data/County_MedianListingPrice_AllHomes.csv'

# Years to be retrieved from census API
years = np.arange(2010, 2017, 1)

# %% [markdown]
# ### Getting Census data from API

# %%
# Run Census Search to retrieve data on all Atlanta metro counties
array_census_data = []

print_message("Starting retrieving data from Census API")

# Iterate throught the years array and call the Census API:
for year in years:
    census_API = Census(api_key, year = year)

    array_census_data.append(pd.DataFrame(census_API.acs5.get(get_fields(), get_filters())).rename(columns = get_column_des(year)))
    
    print(f"Processing data from census on year:{year}")


print_message("Retrieving data from Census API done")
# Out:
# -----------------------------------------
# Starting retrieving data from Census API
# -----------------------------------------
# Processing data from census on year:2010
# Processing data from census on year:2011
# Processing data from census on year:2012
# Processing data from census on year:2013
# Processing data from census on year:2014
# Processing data from census on year:2015
# Processing data from census on year:2016
# -----------------------------------------
# Retrieving data from Census API done
# -----------------------------------------

# %% [markdown]
# ### Census Data Munging from API

# %%
# Merge all the datasets previously retrieved.
census_data = get_merged_data(array_census_data, ['Name', 'State', 'MunicipalCodeFIPS'])

# Delete columns that we no longer use.
census_data.drop(columns="State", inplace=True)

# Insert index to the new and merged DataFrame.
census_data.set_index(["MunicipalCodeFIPS", "Name"], inplace=True)

# Show dataframe.
census_data.head(18)
# Out:
#                                               Median Age 2010  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                 32.9
# 015               Bartow County, Georgia                 36.1
# 045               Carroll County, Georgia                33.2
# 057               Cherokee County, Georgia               35.7
# 063               Clayton County, Georgia                31.1
# 067               Cobb County, Georgia                   34.9
# 077               Coweta County, Georgia                 36.1
# 085               Dawson County, Georgia                 40.7
# 089               DeKalb County, Georgia                 33.9
# 097               Douglas County, Georgia                34.5
# 113               Fayette County, Georgia                41.4
# 117               Forsyth County, Georgia                36.3
# 121               Fulton County, Georgia                 34.0
# 135               Gwinnett County, Georgia               33.3
# 151               Henry County, Georgia                  34.8
# 171               Lamar County, Georgia                  37.7
# 199               Meriwether County, Georgia             38.9
# 227               Pickens County, Georgia                40.8
#
#                                               Population 2010  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia              66359.0
# 015               Bartow County, Georgia              97423.0
# 045               Carroll County, Georgia            109227.0
# 057               Cherokee County, Georgia           206283.0
# 063               Clayton County, Georgia            260156.0
# 067               Cobb County, Georgia               677402.0
# 077               Coweta County, Georgia             121528.0
# 085               Dawson County, Georgia              21758.0
# 089               DeKalb County, Georgia             685371.0
# 097               Douglas County, Georgia            127800.0
# 113               Fayette County, Georgia            105344.0
# 117               Forsyth County, Georgia            163885.0
# 121               Fulton County, Georgia             886982.0
# 135               Gwinnett County, Georgia           778022.0
# 151               Henry County, Georgia              193717.0
# 171               Lamar County, Georgia               17837.0
# 199               Meriwether County, Georgia          22425.0
# 227               Pickens County, Georgia             29155.0
#
#                                               Poverty Count 2010  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                  8295.0
# 015               Bartow County, Georgia                 13472.0
# 045               Carroll County, Georgia                18339.0
# 057               Cherokee County, Georgia               15143.0
# 063               Clayton County, Georgia                42408.0
# 067               Cobb County, Georgia                   71201.0
# 077               Coweta County, Georgia                 12317.0
# 085               Dawson County, Georgia                  2584.0
# 089               DeKalb County, Georgia                107715.0
# 097               Douglas County, Georgia                14309.0
# 113               Fayette County, Georgia                 4906.0
# 117               Forsyth County, Georgia                 9828.0
# 121               Fulton County, Georgia                131531.0
# 135               Gwinnett County, Georgia               85096.0
# 151               Henry County, Georgia                  15898.0
# 171               Lamar County, Georgia                   3521.0
# 199               Meriwether County, Georgia              3635.0
# 227               Pickens County, Georgia                 3316.0
#
#                                               Household Income 2010  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                    48958.0
# 015               Bartow County, Georgia                    49216.0
# 045               Carroll County, Georgia                   45559.0
# 057               Cherokee County, Georgia                  66320.0
# 063               Clayton County, Georgia                   43311.0
# 067               Cobb County, Georgia                      65522.0
# 077               Coweta County, Georgia                    61550.0
# 085               Dawson County, Georgia                    51128.0
# 089               DeKalb County, Georgia                    51349.0
# 097               Douglas County, Georgia                   55852.0
# 113               Fayette County, Georgia                   82216.0
# 117               Forsyth County, Georgia                   87605.0
# 121               Fulton County, Georgia                    56709.0
# 135               Gwinnett County, Georgia                  63219.0
# 151               Henry County, Georgia                     63923.0
# 171               Lamar County, Georgia                     37536.0
# 199               Meriwether County, Georgia                37845.0
# 227               Pickens County, Georgia                   49945.0
#
#                                               Per Capita Income 2010  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                     20882.0
# 015               Bartow County, Georgia                     22241.0
# 045               Carroll County, Georgia                    20523.0
# 057               Cherokee County, Georgia                   30217.0
# 063               Clayton County, Georgia                    18958.0
# 067               Cobb County, Georgia                       33110.0
# 077               Coweta County, Georgia                     26161.0
# 085               Dawson County, Georgia                     25557.0
# 089               DeKalb County, Georgia                     28412.0
# 097               Douglas County, Georgia                    24515.0
# 113               Fayette County, Georgia                    35076.0
# 117               Forsyth County, Georgia                    35385.0
# 121               Fulton County, Georgia                     37211.0
# 135               Gwinnett County, Georgia                   26901.0
# 151               Henry County, Georgia                      25773.0
# 171               Lamar County, Georgia                      17725.0
# 199               Meriwether County, Georgia                 18295.0
# 227               Pickens County, Georgia                    25892.0
#
#                                               Median Value Housing Units 2010  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                             138900.0
# 015               Bartow County, Georgia                             146800.0
# 045               Carroll County, Georgia                            139900.0
# 057               Cherokee County, Georgia                           201900.0
# 063               Clayton County, Georgia                            127800.0
# 067               Cobb County, Georgia                               211000.0
# 077               Coweta County, Georgia                             177900.0
# 085               Dawson County, Georgia                             201400.0
# 089               DeKalb County, Georgia                             190000.0
# 097               Douglas County, Georgia                            157300.0
# 113               Fayette County, Georgia                            252700.0
# 117               Forsyth County, Georgia                            276700.0
# 121               Fulton County, Georgia                             253100.0
# 135               Gwinnett County, Georgia                           194200.0
# 151               Henry County, Georgia                              171500.0
# 171               Lamar County, Georgia                              114100.0
# 199               Meriwether County, Georgia                          95600.0
# 227               Pickens County, Georgia                            170600.0
#
#                                              Median Age 2011 Population 2011  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                33.1           68061
# 015               Bartow County, Georgia                36.2           98905
# 045               Carroll County, Georgia               33.5          110292
# 057               Cherokee County, Georgia              36.1          211316
# 063               Clayton County, Georgia               31.3          260756
# 067               Cobb County, Georgia                  35.2          684468
# 077               Coweta County, Georgia                36.4          124695
# 085               Dawson County, Georgia                40.3           22121
# 089               DeKalb County, Georgia                34.1          690003
# 097               Douglas County, Georgia               34.8          130473
# 113               Fayette County, Georgia                 42          106094
# 117               Forsyth County, Georgia               36.6          170815
# 121               Fulton County, Georgia                34.1          907811
# 135               Gwinnett County, Georgia              33.6          794872
# 151               Henry County, Georgia                 35.1          199115
# 171               Lamar County, Georgia                   38           18035
# 199               Meriwether County, Georgia            40.3           22213
# 227               Pickens County, Georgia               41.5           29406
#
#                                              Poverty Count 2011  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                   8912
# 015               Bartow County, Georgia                  15076
# 045               Carroll County, Georgia                 19253
# 057               Cherokee County, Georgia                16113
# 063               Clayton County, Georgia                 46881
# 067               Cobb County, Georgia                    76183
# 077               Coweta County, Georgia                  13724
# 085               Dawson County, Georgia                   2949
# 089               DeKalb County, Georgia                 115584
# 097               Douglas County, Georgia                 16287
# 113               Fayette County, Georgia                  6218
# 117               Forsyth County, Georgia                 11157
# 121               Fulton County, Georgia                 139609
# 135               Gwinnett County, Georgia                97463
# 151               Henry County, Georgia                   18872
# 171               Lamar County, Georgia                    3492
# 199               Meriwether County, Georgia               4071
# 227               Pickens County, Georgia                  3422
#
#                                              Household Income 2011  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                     50604
# 015               Bartow County, Georgia                     49060
# 045               Carroll County, Georgia                    45752
# 057               Cherokee County, Georgia                   66717
# 063               Clayton County, Georgia                    42936
# 067               Cobb County, Georgia                       65423
# 077               Coweta County, Georgia                     61015
# 085               Dawson County, Georgia                     51989
# 089               DeKalb County, Georgia                     51712
# 097               Douglas County, Georgia                    54763
# 113               Fayette County, Georgia                    81498
# 117               Forsyth County, Georgia                    88262
# 121               Fulton County, Georgia                     57582
# 135               Gwinnett County, Georgia                   63076
# 151               Henry County, Georgia                      64251
# 171               Lamar County, Georgia                      39684
# 199               Meriwether County, Georgia                 37028
# 227               Pickens County, Georgia                    50582
#
#                                                            ...                 \
# MunicipalCodeFIPS Name                                     ...
# 013               Barrow County, Georgia                   ...
# 015               Bartow County, Georgia                   ...
# 045               Carroll County, Georgia                  ...
# 057               Cherokee County, Georgia                 ...
# 063               Clayton County, Georgia                  ...
# 067               Cobb County, Georgia                     ...
# 077               Coweta County, Georgia                   ...
# 085               Dawson County, Georgia                   ...
# 089               DeKalb County, Georgia                   ...
# 097               Douglas County, Georgia                  ...
# 113               Fayette County, Georgia                  ...
# 117               Forsyth County, Georgia                  ...
# 121               Fulton County, Georgia                   ...
# 135               Gwinnett County, Georgia                 ...
# 151               Henry County, Georgia                    ...
# 171               Lamar County, Georgia                    ...
# 199               Meriwether County, Georgia               ...
# 227               Pickens County, Georgia                  ...
#
#                                              Poverty Count 2015  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                10902.0
# 015               Bartow County, Georgia                15819.0
# 045               Carroll County, Georgia               22441.0
# 057               Cherokee County, Georgia              24273.0
# 063               Clayton County, Georgia               65787.0
# 067               Cobb County, Georgia                  87880.0
# 077               Coweta County, Georgia                17489.0
# 085               Dawson County, Georgia                 3156.0
# 089               DeKalb County, Georgia               135469.0
# 097               Douglas County, Georgia               22118.0
# 113               Fayette County, Georgia                9129.0
# 117               Forsyth County, Georgia               13547.0
# 121               Fulton County, Georgia               167391.0
# 135               Gwinnett County, Georgia             117553.0
# 151               Henry County, Georgia                 27162.0
# 171               Lamar County, Georgia                  3713.0
# 199               Meriwether County, Georgia             4733.0
# 227               Pickens County, Georgia                3418.0
#
#                                              Household Income 2015  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                   52012.0
# 015               Bartow County, Georgia                   48893.0
# 045               Carroll County, Georgia                  43586.0
# 057               Cherokee County, Georgia                 68926.0
# 063               Clayton County, Georgia                  40938.0
# 067               Cobb County, Georgia                     65873.0
# 077               Coweta County, Georgia                   62461.0
# 085               Dawson County, Georgia                   56943.0
# 089               DeKalb County, Georgia                   51376.0
# 097               Douglas County, Georgia                  53881.0
# 113               Fayette County, Georgia                  79066.0
# 117               Forsyth County, Georgia                  88816.0
# 121               Fulton County, Georgia                   57207.0
# 135               Gwinnett County, Georgia                 60289.0
# 151               Henry County, Georgia                    60424.0
# 171               Lamar County, Georgia                    40344.0
# 199               Meriwether County, Georgia               35832.0
# 227               Pickens County, Georgia                  54123.0
#
#                                               Per Capita Income 2015  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                     21411.0
# 015               Bartow County, Georgia                     22592.0
# 045               Carroll County, Georgia                    21320.0
# 057               Cherokee County, Georgia                   30595.0
# 063               Clayton County, Georgia                    18107.0
# 067               Cobb County, Georgia                       33778.0
# 077               Coweta County, Georgia                     28106.0
# 085               Dawson County, Georgia                     28832.0
# 089               DeKalb County, Georgia                     29486.0
# 097               Douglas County, Georgia                    23158.0
# 113               Fayette County, Georgia                    36362.0
# 117               Forsyth County, Georgia                    35696.0
# 121               Fulton County, Georgia                     37926.0
# 135               Gwinnett County, Georgia                   25831.0
# 151               Henry County, Georgia                      24996.0
# 171               Lamar County, Georgia                      19217.0
# 199               Meriwether County, Georgia                 18059.0
# 227               Pickens County, Georgia                    27720.0
#
#                                               Median Value Housing Units 2015  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                             119700.0
# 015               Bartow County, Georgia                             123800.0
# 045               Carroll County, Georgia                            112100.0
# 057               Cherokee County, Georgia                           190500.0
# 063               Clayton County, Georgia                             85200.0
# 067               Cobb County, Georgia                               197400.0
# 077               Coweta County, Georgia                             181000.0
# 085               Dawson County, Georgia                             188300.0
# 089               DeKalb County, Georgia                             163000.0
# 097               Douglas County, Georgia                            121300.0
# 113               Fayette County, Georgia                            229500.0
# 117               Forsyth County, Georgia                            267300.0
# 121               Fulton County, Georgia                             241300.0
# 135               Gwinnett County, Georgia                           167700.0
# 151               Henry County, Georgia                              140300.0
# 171               Lamar County, Georgia                              124300.0
# 199               Meriwether County, Georgia                          89800.0
# 227               Pickens County, Georgia                            175000.0
#
#                                               Median Age 2016  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                 35.0
# 015               Bartow County, Georgia                 37.4
# 045               Carroll County, Georgia                34.1
# 057               Cherokee County, Georgia               37.7
# 063               Clayton County, Georgia                32.4
# 067               Cobb County, Georgia                   36.2
# 077               Coweta County, Georgia                 37.9
# 085               Dawson County, Georgia                 42.8
# 089               DeKalb County, Georgia                 35.2
# 097               Douglas County, Georgia                36.1
# 113               Fayette County, Georgia                43.5
# 117               Forsyth County, Georgia                38.1
# 121               Fulton County, Georgia                 35.0
# 135               Gwinnett County, Georgia               34.8
# 151               Henry County, Georgia                  36.5
# 171               Lamar County, Georgia                  38.4
# 199               Meriwether County, Georgia             42.3
# 227               Pickens County, Georgia                44.8
#
#                                               Population 2016  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia              73340.0
# 015               Bartow County, Georgia             101942.0
# 045               Carroll County, Georgia            113756.0
# 057               Cherokee County, Georgia           230629.0
# 063               Clayton County, Georgia            270269.0
# 067               Cobb County, Georgia               728388.0
# 077               Coweta County, Georgia             135625.0
# 085               Dawson County, Georgia              22939.0
# 089               DeKalb County, Georgia             723902.0
# 097               Douglas County, Georgia            138283.0
# 113               Fayette County, Georgia            109495.0
# 117               Forsyth County, Georgia            203841.0
# 121               Fulton County, Georgia             996757.0
# 135               Gwinnett County, Georgia           874242.0
# 151               Henry County, Georgia              214171.0
# 171               Lamar County, Georgia               18195.0
# 199               Meriwether County, Georgia          21195.0
# 227               Pickens County, Georgia             29992.0
#
#                                               Poverty Count 2016  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                 10548.0
# 015               Bartow County, Georgia                 14899.0
# 045               Carroll County, Georgia                21157.0
# 057               Cherokee County, Georgia               22891.0
# 063               Clayton County, Georgia                64326.0
# 067               Cobb County, Georgia                   83479.0
# 077               Coweta County, Georgia                 16138.0
# 085               Dawson County, Georgia                  3028.0
# 089               DeKalb County, Georgia                134830.0
# 097               Douglas County, Georgia                20805.0
# 113               Fayette County, Georgia                 7774.0
# 117               Forsyth County, Georgia                13024.0
# 121               Fulton County, Georgia                163674.0
# 135               Gwinnett County, Georgia              112999.0
# 151               Henry County, Georgia                  25657.0
# 171               Lamar County, Georgia                   3746.0
# 199               Meriwether County, Georgia              4943.0
# 227               Pickens County, Georgia                 3058.0
#
#                                               Household Income 2016  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                    53133.0
# 015               Bartow County, Georgia                    50565.0
# 045               Carroll County, Georgia                   45486.0
# 057               Cherokee County, Georgia                  72586.0
# 063               Clayton County, Georgia                   42470.0
# 067               Cobb County, Georgia                      68818.0
# 077               Coweta County, Georgia                    65244.0
# 085               Dawson County, Georgia                    59265.0
# 089               DeKalb County, Georgia                    52623.0
# 097               Douglas County, Georgia                   57384.0
# 113               Fayette County, Georgia                   81689.0
# 117               Forsyth County, Georgia                   91842.0
# 121               Fulton County, Georgia                    58851.0
# 135               Gwinnett County, Georgia                  61865.0
# 151               Henry County, Georgia                     62561.0
# 171               Lamar County, Georgia                     40364.0
# 199               Meriwether County, Georgia                34989.0
# 227               Pickens County, Georgia                   56769.0
#
#                                               Per Capita Income 2016  \
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                     21978.0
# 015               Bartow County, Georgia                     23376.0
# 045               Carroll County, Georgia                    22002.0
# 057               Cherokee County, Georgia                   32002.0
# 063               Clayton County, Georgia                    18728.0
# 067               Cobb County, Georgia                       34891.0
# 077               Coweta County, Georgia                     29769.0
# 085               Dawson County, Georgia                     29958.0
# 089               DeKalb County, Georgia                     30517.0
# 097               Douglas County, Georgia                    24471.0
# 113               Fayette County, Georgia                    38493.0
# 117               Forsyth County, Georgia                    37686.0
# 121               Fulton County, Georgia                     39101.0
# 135               Gwinnett County, Georgia                   26749.0
# 151               Henry County, Georgia                      25727.0
# 171               Lamar County, Georgia                      19143.0
# 199               Meriwether County, Georgia                 19626.0
# 227               Pickens County, Georgia                    28637.0
#
#                                               Median Value Housing Units 2016
# MunicipalCodeFIPS Name
# 013               Barrow County, Georgia                             123200.0
# 015               Bartow County, Georgia                             128200.0
# 045               Carroll County, Georgia                            113700.0
# 057               Cherokee County, Georgia                           204400.0
# 063               Clayton County, Georgia                             86700.0
# 067               Cobb County, Georgia                               205600.0
# 077               Coweta County, Georgia                             182300.0
# 085               Dawson County, Georgia                             196400.0
# 089               DeKalb County, Georgia                             168100.0
# 097               Douglas County, Georgia                            127400.0
# 113               Fayette County, Georgia                            240200.0
# 117               Forsyth County, Georgia                            281400.0
# 121               Fulton County, Georgia                             252700.0
# 135               Gwinnett County, Georgia                           173000.0
# 151               Henry County, Georgia                              146100.0
# 171               Lamar County, Georgia                              121000.0
# 199               Meriwether County, Georgia                          88400.0
# 227               Pickens County, Georgia                            181100.0
#
# [18 rows x 42 columns]

# %% [markdown]
# ### Zillow Data Munging from .CSV

# %%
# Get Zillow CSV historical data.
# Source: https://www.zillow.com/research/data/
zillow_data = pd.read_csv(zillow_csv)

# Defining FIPS for State and Counties.
georgia_fips = 13
county_fips = ['121','135','089','067','063','057','151','117','097','077','045','113','015','297','013','227','085','199','171']

# Filtering CSV by State and Countues.
metro_atlanta_data = zillow_data[(zillow_data["StateCodeFIPS"] == georgia_fips) & (zillow_data["MunicipalCodeFIPS"].isin(county_fips))]

# Delete columns no longer needed.
metro_atlanta_data = metro_atlanta_data.drop(columns=["State", "Metro", "StateCodeFIPS", "SizeRank", "RegionName"])

# Define new index for DataFrame.
metro_atlanta_data.set_index(["MunicipalCodeFIPS"], inplace=True)

# Transpose DataFrame in order to filter year-month with ease.
metro_atlanta_data = metro_atlanta_data.T

# Remove index.
metro_atlanta_data.reset_index(inplace=True)

# Replace text for year-month to year.
metro_atlanta_data["year"] = metro_atlanta_data["index"].apply(lambda x: x[:(len(x) - x.find("-")) + 1])

# Delete columns no longer needed.
metro_atlanta_data = metro_atlanta_data.drop(columns=["index"])

# Group data by year and get the average amount.
metro_atlanta_data = metro_atlanta_data.groupby("year").mean()

# Transpose again the DataFrame.
metro_atlanta_data = metro_atlanta_data.T

# Decorate the DataFrame with columns description.
metro_atlanta_data.rename(columns=get_zillow_column_des(), inplace=True)

# Show DataFrame.
metro_atlanta_data.head()
# Out:
# year               Zillow Median Value Housing 2010  \
# MunicipalCodeFIPS
# 121                                   214815.000000
# 135                                   167389.041667
# 89                                    160808.333333
# 67                                    193800.000000
# 63                                     68775.000000
#
# year               Zillow Median Value Housing 2011  \
# MunicipalCodeFIPS
# 121                                       184231.25
# 135                                       141300.00
# 89                                        126400.00
# 67                                        172334.50
# 63                                         52012.50
#
# year               Zillow Median Value Housing 2012  \
# MunicipalCodeFIPS
# 121                                   197416.666667
# 135                                   141926.666667
# 89                                    124391.666667
# 67                                    180977.958333
# 63                                     50278.041667
#
# year               Zillow Median Value Housing 2013  \
# MunicipalCodeFIPS
# 121                                   233341.666667
# 135                                   181081.666667
# 89                                    162425.000000
# 67                                    216000.000000
# 63                                     61483.333333
#
# year               Zillow Median Value Housing 2014  \
# MunicipalCodeFIPS
# 121                                   251515.500000
# 135                                   200884.583333
# 89                                    168195.833333
# 67                                    235351.708333
# 63                                     74382.541667
#
# year               Zillow Median Value Housing 2015  \
# MunicipalCodeFIPS
# 121                                   263650.416667
# 135                                   218675.083333
# 89                                    172700.000000
# 67                                    250066.250000
# 63                                     94483.250000
#
# year               Zillow Median Value Housing 2016  \
# MunicipalCodeFIPS
# 121                                   303332.500000
# 135                                   237650.083333
# 89                                    192253.458333
# 67                                    283522.916667
# 63                                    106954.625000
#
# year               Zillow Median Value Housing 2017  \
# MunicipalCodeFIPS
# 121                                   352743.125000
# 135                                   255407.375000
# 89                                    229408.500000
# 67                                    299803.291667
# 63                                    124261.791667
#
# year               Zillow Median Value Housing 2018
# MunicipalCodeFIPS
# 121                                     382600.0000
# 135                                     279210.3125
# 89                                      261293.1250
# 67                                      317735.6250
# 63                                      139737.4375

# %% [markdown]
# ### Merging Census and Zillow DataFrames

# %%
census_data_reset = census_data.reset_index()

census_data_reset["MunicipalCodeFIPS"] = census_data_reset["MunicipalCodeFIPS"].astype("l")

metro_atlanta_data_reset = metro_atlanta_data.reset_index()

zillow_census_data = pd.merge(census_data_reset, metro_atlanta_data_reset, how="outer", left_on="MunicipalCodeFIPS", right_on="MunicipalCodeFIPS")

zillow_census_data.set_index(["MunicipalCodeFIPS", "Name"], inplace=True)

zillow_census_data.head()
# Out:
#                                             Median Age 2010  Population 2010  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia               32.9          66359.0
# 15                Bartow County, Georgia               36.1          97423.0
# 45                Carroll County, Georgia              33.2         109227.0
# 57                Cherokee County, Georgia             35.7         206283.0
# 63                Clayton County, Georgia              31.1         260156.0
#
#                                             Poverty Count 2010  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                8295.0
# 15                Bartow County, Georgia               13472.0
# 45                Carroll County, Georgia              18339.0
# 57                Cherokee County, Georgia             15143.0
# 63                Clayton County, Georgia              42408.0
#
#                                             Household Income 2010  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                  48958.0
# 15                Bartow County, Georgia                  49216.0
# 45                Carroll County, Georgia                 45559.0
# 57                Cherokee County, Georgia                66320.0
# 63                Clayton County, Georgia                 43311.0
#
#                                             Per Capita Income 2010  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                   20882.0
# 15                Bartow County, Georgia                   22241.0
# 45                Carroll County, Georgia                  20523.0
# 57                Cherokee County, Georgia                 30217.0
# 63                Clayton County, Georgia                  18958.0
#
#                                             Median Value Housing Units 2010  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                           138900.0
# 15                Bartow County, Georgia                           146800.0
# 45                Carroll County, Georgia                          139900.0
# 57                Cherokee County, Georgia                         201900.0
# 63                Clayton County, Georgia                          127800.0
#
#                                            Median Age 2011 Population 2011  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia              33.1           68061
# 15                Bartow County, Georgia              36.2           98905
# 45                Carroll County, Georgia             33.5          110292
# 57                Cherokee County, Georgia            36.1          211316
# 63                Clayton County, Georgia             31.3          260756
#
#                                            Poverty Count 2011  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                 8912
# 15                Bartow County, Georgia                15076
# 45                Carroll County, Georgia               19253
# 57                Cherokee County, Georgia              16113
# 63                Clayton County, Georgia               46881
#
#                                            Household Income 2011  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                   50604
# 15                Bartow County, Georgia                   49060
# 45                Carroll County, Georgia                  45752
# 57                Cherokee County, Georgia                 66717
# 63                Clayton County, Georgia                  42936
#
#                                                           ...                 \
# MunicipalCodeFIPS Name                                    ...
# 13                Barrow County, Georgia                  ...
# 15                Bartow County, Georgia                  ...
# 45                Carroll County, Georgia                 ...
# 57                Cherokee County, Georgia                ...
# 63                Clayton County, Georgia                 ...
#
#                                            Median Value Housing Units 2016  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                          123200.0
# 15                Bartow County, Georgia                          128200.0
# 45                Carroll County, Georgia                         113700.0
# 57                Cherokee County, Georgia                        204400.0
# 63                Clayton County, Georgia                          86700.0
#
#                                            Zillow Median Value Housing 2010  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                      130150.000000
# 15                Bartow County, Georgia                      135982.375000
# 45                Carroll County, Georgia                     116294.583333
# 57                Cherokee County, Georgia                    206352.166667
# 63                Clayton County, Georgia                      68775.000000
#
#                                             Zillow Median Value Housing 2011  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                       101891.666667
# 15                Bartow County, Georgia                       121733.958333
# 45                Carroll County, Georgia                       92822.916667
# 57                Cherokee County, Georgia                     181889.166667
# 63                Clayton County, Georgia                       52012.500000
#
#                                             Zillow Median Value Housing 2012  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                        96191.666667
# 15                Bartow County, Georgia                       111964.583333
# 45                Carroll County, Georgia                       90464.333333
# 57                Cherokee County, Georgia                     181713.125000
# 63                Clayton County, Georgia                       50278.041667
#
#                                             Zillow Median Value Housing 2013  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                       121120.833333
# 15                Bartow County, Georgia                       127450.000000
# 45                Carroll County, Georgia                      113433.333333
# 57                Cherokee County, Georgia                     213870.208333
# 63                Clayton County, Georgia                       61483.333333
#
#                                             Zillow Median Value Housing 2014  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                       143908.875000
# 15                Bartow County, Georgia                       144440.000000
# 45                Carroll County, Georgia                      128007.833333
# 57                Cherokee County, Georgia                     236366.666667
# 63                Clayton County, Georgia                       74382.541667
#
#                                             Zillow Median Value Housing 2015  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                       156055.250000
# 15                Bartow County, Georgia                       158712.500000
# 45                Carroll County, Georgia                      132591.666667
# 57                Cherokee County, Georgia                     257103.416667
# 63                Clayton County, Georgia                       94483.250000
#
#                                             Zillow Median Value Housing 2016  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                       169008.333333
# 15                Bartow County, Georgia                       180064.666667
# 45                Carroll County, Georgia                      144666.625000
# 57                Cherokee County, Georgia                     283355.041667
# 63                Clayton County, Georgia                      106954.625000
#
#                                             Zillow Median Value Housing 2017  \
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                       184349.583333
# 15                Bartow County, Georgia                       196071.875000
# 45                Carroll County, Georgia                      156516.666667
# 57                Cherokee County, Georgia                     302666.958333
# 63                Clayton County, Georgia                      124261.791667
#
#                                             Zillow Median Value Housing 2018
# MunicipalCodeFIPS Name
# 13                Barrow County, Georgia                         201605.6250
# 15                Bartow County, Georgia                         205881.2500
# 45                Carroll County, Georgia                        173343.3750
# 57                Cherokee County, Georgia                       324638.3125
# 63                Clayton County, Georgia                        139737.4375
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Zillow Median value housing Plot

# %%
display(HTML(f'<marquee>All these results are based on the calculated MEDIAN from 2010 to 2016 from Value Housing</marquee>'))

fig = plt.figure()

ax = fig.subplots()

zillow_value_housing = zillow_census_data[['Zillow Median Value Housing 2010',
             'Zillow Median Value Housing 2011',
             'Zillow Median Value Housing 2012',
             'Zillow Median Value Housing 2013',
             'Zillow Median Value Housing 2014',
             'Zillow Median Value Housing 2015',
             'Zillow Median Value Housing 2016'
            ]].astype('float').T.mean()

zillow_value_housing = zillow_value_housing.reset_index()

zillow_value_housing = zillow_value_housing.drop(columns=["MunicipalCodeFIPS"])

zillow_value_housing = zillow_value_housing.set_index("Name")

zillow_value_housing = zillow_value_housing[0].sort_values(ascending=False)

zillow_value_housing_x = [(x[:(len(x) - x.find(" County,")) - 10]) for x in zillow_value_housing.index.values]

ax.plot(zillow_value_housing_x, zillow_value_housing, linewidth = 2, color="g")
ax.scatter(zillow_value_housing_x, zillow_value_housing, label=None, s = 80, color="g")
ax.bar(zillow_value_housing_x, zillow_value_housing, color="g", alpha=0.2)

ax.set_title("Zillow Median Value Housing")
ax.set_xlabel("COUNTIES")
ax.set_ylabel("Housing values ($)")

ax.grid()

fig.set_size_inches(20, 5)
# Out:
# <marquee>All these results are based on the calculated MEDIAN from 2010 to 2016 from Value Housing</marquee>

# %% [markdown]
# ### Census Median Value Houses PLOT

# %%
display(HTML(f'<marquee>All these results are based on the calculated MEDIAN from 2010 to 2016 from Value Housing</marquee>'))

fig, ax = plt.subplots()

census_value_housing = zillow_census_data[['Median Value Housing Units 2010',
             'Median Value Housing Units 2011',
             'Median Value Housing Units 2012',
             'Median Value Housing Units 2013',
             'Median Value Housing Units 2014',
             'Median Value Housing Units 2015',
             'Median Value Housing Units 2016'
            ]].astype('float').T.mean()

census_value_housing = census_value_housing.reset_index()

census_value_housing = census_value_housing.drop(columns=["MunicipalCodeFIPS"])

census_value_housing = census_value_housing.set_index("Name")

census_value_housing = census_value_housing[0].sort_values(ascending=False)

census_value_housing_x = [(x[:(len(x) - x.find(" County,")) - 10]) for x in census_value_housing.index.values]

ax.plot(census_value_housing_x, census_value_housing, linewidth = 2, color="#800000")
ax.scatter(census_value_housing_x, census_value_housing, label=None, s = 80, color="#800000")
ax.bar(census_value_housing_x, census_value_housing, color="#800000", alpha=0.2)

ax.set_title("Census Median Value Housing Units")
ax.set_xlabel("COUNTIES")
ax.set_ylabel("Housing Median Value Prices ($)")

ax.grid()
fig.set_size_inches(20, 5)
# Out:
# <marquee>All these results are based on the calculated MEDIAN from 2010 to 2016 from Value Housing</marquee>

# %% [markdown]
# ### Income Per-Capita PLOT

# %%
display(HTML(f'<marquee>All these results are based on the calculated MEDIAN from 2010 to 2016 from INCOME PER CAPITA</marquee>'))

fig, ax = plt.subplots()

median_income_capita = census_data[['Per Capita Income 2010',
             'Per Capita Income 2011',
             'Per Capita Income 2012',
             'Per Capita Income 2013',
             'Per Capita Income 2014',
             'Per Capita Income 2015',
             'Per Capita Income 2016'
            ]].astype('float').T.mean()

median_income_capita = median_income_capita.reset_index()

median_income_capita = median_income_capita.drop(columns=["MunicipalCodeFIPS"])

median_income_capita = median_income_capita.set_index("Name")

median_income_capita = median_income_capita[0].sort_values(ascending=False)

median_income_capita_x = [(x[:(len(x) - x.find(" County,")) - 10]) for x in median_income_capita.index.values]


ax.plot(median_income_capita_x, median_income_capita, linewidth = 2, color="#336699")
ax.scatter(median_income_capita_x, median_income_capita, label=None, s = 80, color="#336699")
ax.bar(median_income_capita_x, median_income_capita, color="#336699", alpha=0.2)

ax.set_title("Median Income Per-Capita")
ax.set_xlabel("COUNTIES")
ax.set_ylabel("Income Per-Capita ($)")

ax.grid()

fig.set_size_inches(16, 5)
# Out:
# <marquee>All these results are based on the calculated MEDIAN from 2010 to 2016 from INCOME PER CAPITA</marquee>

# %% [markdown]
# ### Household Income by year Plot

# %%
fig, ax = plt.subplots()

median_income_house_hold = census_data[['Household Income 2010',
             'Household Income 2011',
             'Household Income 2012',
             'Household Income 2013',
             'Household Income 2014',
             'Household Income 2015',
             'Household Income 2016'
            ]].astype('float').T.mean()

median_income_house_hold = median_income_house_hold.reset_index()

median_income_house_hold = median_income_house_hold.drop(columns=["MunicipalCodeFIPS"])

median_income_house_hold = median_income_house_hold.set_index("Name")

median_income_house_hold = median_income_house_hold[0].sort_values(ascending=False)

median_income_house_hold_x = [(x[:(len(x) - x.find(" County,")) - 10]) for x in median_income_capita.index.values]


ax.plot(median_income_house_hold_x, median_income_house_hold, linewidth = 2, color="#800000")
ax.scatter(median_income_house_hold_x, median_income_house_hold, label=None, s = 80, color="#800000")
ax.bar(median_income_house_hold_x, median_income_house_hold, color="#800000", alpha=0.2)

ax.set_title("Median House hold Income per County")
ax.set_xlabel("COUNTIES")
ax.set_ylabel("Income House Hold ($)")

ax.grid()

fig.set_size_inches(16, 5)

# %% [markdown]
# ### Median Value Housing vs Per Capita Income PLOT

# %%
fig, ax = plt.subplots()

ax.scatter(income_capita["Per Capita Income 2010"], zillow_census_data["Zillow Median Value Housing 2010"])
ax.scatter(income_capita["Per Capita Income 2011"], zillow_census_data["Zillow Median Value Housing 2011"])
ax.scatter(income_capita["Per Capita Income 2012"], zillow_census_data["Zillow Median Value Housing 2012"])
ax.scatter(income_capita["Per Capita Income 2013"], zillow_census_data["Zillow Median Value Housing 2013"])
ax.scatter(income_capita["Per Capita Income 2014"], zillow_census_data["Zillow Median Value Housing 2014"])
ax.scatter(income_capita["Per Capita Income 2015"], zillow_census_data["Zillow Median Value Housing 2015"])
ax.scatter(income_capita["Per Capita Income 2016"], zillow_census_data["Zillow Median Value Housing 2016"])

ax.set_xlabel("PER CAPITA INCOME")
ax.set_ylabel("Zillow Median Value Housing ($)")
plt.legend()
plt.grid()

fig.set_size_inches(16, 10)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3c02af2e3a7b> in <module>()
#       1 fig, ax = plt.subplots()
#       2
# ----> 3 ax.scatter(income_capita["Per Capita Income 2010"], zillow_census_data["Zillow Median Value Housing 2010"])
#       4 ax.scatter(income_capita["Per Capita Income 2011"], zillow_census_data["Zillow Median Value Housing 2011"])
#       5 ax.scatter(income_capita["Per Capita Income 2012"], zillow_census_data["Zillow Median Value Housing 2012"])
#
# NameError: name 'income_capita' is not defined

# %% [markdown]
# ### Median Value Housing vs Per Capita Income (2010-2016) PLOT

# %%
display(HTML(f'<marquee>All these results are based on the average data from 2010 until 2016 for Percapita Income vs Median Value Housing</marquee>'))

zillow_census_data_mean = zillow_census_data[["Zillow Median Value Housing 2010",
                                             "Zillow Median Value Housing 2011",
                                             "Zillow Median Value Housing 2012",
                                             "Zillow Median Value Housing 2013",
                                             "Zillow Median Value Housing 2014",
                                             "Zillow Median Value Housing 2015",
                                             "Zillow Median Value Housing 2016"]].astype('float').T.mean()

income_capita_mean = income_capita[["Per Capita Income 2010",
                                             "Per Capita Income 2011",
                                             "Per Capita Income 2012",
                                             "Per Capita Income 2013",
                                             "Per Capita Income 2014",
                                             "Per Capita Income 2015",
                                             "Per Capita Income 2016"]].astype('float').T.mean()

value = linregress(zillow_census_data_mean, income_capita_mean)
display(HTML('<h2>Analysis after line regression</h2>'))
display(HTML(f'<li>p-value: {value.pvalue}</li>'))
display(HTML(f'<li>slope: {value.slope}</li>'))
display(HTML(f'<li>intercept on y: {value.intercept}</li>'))
display(HTML(f'<h4>Regression line formula:</h4>'))
display(HTML(f'<code>Y = {value.intercept} + ({value.slope} * X)</code>'))

fig, ax = plt.subplots()

ax.scatter(income_capita_mean, zillow_census_data_mean, label="Per Capita Income (2010 - 2016)", color="#336699")
print_trendline(income_capita_mean, zillow_census_data_mean)

ax.set_title("Per Capita Income vs Median Value Housing (2010 - 2016)")
ax.set_xlabel("Per Capita Income (2010 - 2016)")
ax.set_ylabel("Zillow Median Value Housing")
ax.set_xlim(18400, 37500)

plt.legend(loc="upper left")
plt.grid()

fig.set_size_inches(16, 10)

# %% [markdown]
# # Population by County

# %%
display(HTML(f'<marquee>All these results are based on Census data from 2010 to 2016 for Population by Counties</marquee>'))

fig, ax = plt.subplots()

census_value_housing = zillow_census_data[['Median Value Housing Units 2010',
             'Population 2011',
             'Population 2012',
             'Population 2013',
             'Population 2014',
             'Population 2015',
             'Population 2016'
            ]].astype('float').T.mean()

census_value_housing = census_value_housing.reset_index()

census_value_housing = census_value_housing.drop(columns=["MunicipalCodeFIPS"])

census_value_housing = census_value_housing.set_index("Name")

census_value_housing = census_value_housing[0].sort_values(ascending=False)

census_value_housing_x = [(x[:(len(x) - x.find(" County,")) - 10]) for x in census_value_housing.index.values]

ax.plot(census_value_housing_x, census_value_housing, linewidth = 2, color="#800000")
ax.scatter(census_value_housing_x, census_value_housing, label=None, s = 80, color="#800000")
ax.bar(census_value_housing_x, census_value_housing, color="#800000", alpha=0.2)

ax.set_title("Census Population")
ax.set_xlabel("COUNTIES")
ax.set_ylabel("Population")

ax.grid()
fig.set_size_inches(20, 5)
# Out:
# <marquee>All these results are based on Census data from 2010 to 2016 for Population by Counties</marquee>
